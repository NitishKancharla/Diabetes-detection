# %%
import numpy as np
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
from tensorflow.keras.preprocessing import image
# Out:
# 2024-05-08 06:41:11.721378: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-08 06:41:11.721477: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-08 06:41:11.827487: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
train_path= '../input/thermography-images-of-diabetic-foot/ThermoDataBase/train'
test_path='../input/thermography-images-of-diabetic-foot/ThermoDataBase/val'

# %%
train_datagen = image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1,
    validation_split =0.2
)
test_datagen= image.ImageDataGenerator(   
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1)

# %%
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size = (224,224),
    batch_size = 4,
    class_mode = 'binary',
    subset='training'
)
val_generator = train_datagen.flow_from_directory(
    train_path,
    target_size = (224,224),
    batch_size = 4,
    class_mode = 'binary',
    subset='validation'
)
test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size = (224,224),
    batch_size = 4,
    shuffle=True,
    class_mode = 'binary')
# Out:
# Found 1156 images belonging to 2 classes.
# Found 288 images belonging to 2 classes.
# Found 422 images belonging to 2 classes.

# %%
base_model = tf.keras.applications.EfficientNetB3(weights='imagenet', input_shape=(224,224,3), include_top=False)
# Freeze layers
for layer in base_model.layers:
    layer.trainable=False
model = Sequential()
model.add(base_model)
model.add(GaussianNoise(0.25))
model.add(GlobalAveragePooling2D())
model.add(Dense(256,activation='relu'))
model.add(BatchNormalization())
model.add(GaussianNoise(0.25))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb3 (Functional)     │ ?                      │    10,783,535 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise (GaussianNoise)  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ ?                      │   0 (unbuilt) │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise_1                │ ?                      │   0 (unbuilt) │
# │ (GaussianNoise)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,783,535 (41.14 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 10,783,535 (41.14 MB)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adamw',
              metrics=['accuracy','AUC','Precision','Recall'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
filepath='best_model.keras'
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history = model.fit(
    train_generator,
    epochs=20,
    validation_data=val_generator,
    steps_per_epoch= 50,
    callbacks=[checkpoint]
    )
# Out:
# Epoch 1/20
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  3/50 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - AUC: 0.9005 - Precision: 1.0000 - Recall: 0.6111 - accuracy: 0.7778 - loss: 0.5832
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715150551.546986     104 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1715150551.619563     104 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - AUC: 0.7911 - Precision: 0.7040 - Recall: 0.7113 - accuracy: 0.7028 - loss: 0.6861
# W0000 00:00:1715150564.564536     104 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.79514, saving model to best_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 82s 373ms/step - AUC: 0.7912 - Precision: 0.7036 - Recall: 0.7115 - accuracy: 0.7026 - loss: 0.6863 - val_AUC: 0.8928 - val_Precision: 0.7640 - val_Recall: 0.8542 - val_accuracy: 0.7951 - val_loss: 0.4224
# Epoch 2/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - AUC: 0.8847 - Precision: 0.8008 - Recall: 0.8039 - accuracy: 0.8011 - loss: 0.4916
# Epoch 2: val_accuracy improved from 0.79514 to 0.82986, saving model to best_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - AUC: 0.8841 - Precision: 0.8002 - Recall: 0.8035 - accuracy: 0.8007 - loss: 0.4923 - val_AUC: 0.9434 - val_Precision: 0.9524 - val_Recall: 0.6944 - val_accuracy: 0.8299 - val_loss: 0.3745
# Epoch 3/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - AUC: 0.8844 - Precision: 0.8374 - Recall: 0.8366 - accuracy: 0.8227 - loss: 0.4353
# Epoch 3: val_accuracy improved from 0.82986 to 0.90972, saving model to best_model.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 178ms/step - AUC: 0.8841 - Precision: 0.8366 - Recall: 0.8356 - accuracy: 0.8220 - loss: 0.4359 - val_AUC: 0.9641 - val_Precision: 0.9403 - val_Recall: 0.8750 - val_accuracy: 0.9097 - val_loss: 0.2561
# Epoch 4/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - AUC: 0.9365 - Precision: 0.9050 - Recall: 0.7631 - accuracy: 0.8201 - loss: 0.3377
# Epoch 4: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - AUC: 0.9362 - Precision: 0.9044 - Recall: 0.7641 - accuracy: 0.8203 - loss: 0.3382 - val_AUC: 0.9327 - val_Precision: 0.7614 - val_Recall: 0.9306 - val_accuracy: 0.8194 - val_loss: 0.3735
# Epoch 5/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - AUC: 0.8855 - Precision: 0.8291 - Recall: 0.8621 - accuracy: 0.8274 - loss: 0.4876
# Epoch 5: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - AUC: 0.8859 - Precision: 0.8282 - Recall: 0.8624 - accuracy: 0.8272 - loss: 0.4862 - val_AUC: 0.8929 - val_Precision: 0.7068 - val_Recall: 0.9375 - val_accuracy: 0.7743 - val_loss: 0.6056
# Epoch 6/20
# 37/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - AUC: 0.8583 - Precision: 0.6251 - Recall: 0.8218 - accuracy: 0.7804 - loss: 0.5144
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 6: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - AUC: 0.8622 - Precision: 0.6450 - Recall: 0.8106 - accuracy: 0.7794 - loss: 0.5011 - val_AUC: 0.9116 - val_Precision: 0.6821 - val_Recall: 0.9236 - val_accuracy: 0.7465 - val_loss: 0.5767
# Epoch 7/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - AUC: 0.9135 - Precision: 0.8766 - Recall: 0.7826 - accuracy: 0.8227 - loss: 0.3740
# Epoch 7: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - AUC: 0.9130 - Precision: 0.8763 - Recall: 0.7821 - accuracy: 0.8224 - loss: 0.3752 - val_AUC: 0.8480 - val_Precision: 0.6143 - val_Recall: 0.9514 - val_accuracy: 0.6771 - val_loss: 0.8543
# Epoch 8/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - AUC: 0.9101 - Precision: 0.8405 - Recall: 0.8067 - accuracy: 0.8044 - loss: 0.3716
# Epoch 8: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - AUC: 0.9101 - Precision: 0.8393 - Recall: 0.8072 - accuracy: 0.8042 - loss: 0.3717 - val_AUC: 0.9368 - val_Precision: 0.7151 - val_Recall: 0.9236 - val_accuracy: 0.7778 - val_loss: 0.4159
# Epoch 9/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - AUC: 0.8978 - Precision: 0.7702 - Recall: 0.8208 - accuracy: 0.8191 - loss: 0.4275
# Epoch 9: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - AUC: 0.8979 - Precision: 0.7711 - Recall: 0.8211 - accuracy: 0.8194 - loss: 0.4268 - val_AUC: 0.9263 - val_Precision: 0.6866 - val_Recall: 0.9583 - val_accuracy: 0.7604 - val_loss: 0.5544
# Epoch 10/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - AUC: 0.9097 - Precision: 0.8354 - Recall: 0.7613 - accuracy: 0.7972 - loss: 0.3971
# Epoch 10: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 142ms/step - AUC: 0.9096 - Precision: 0.8341 - Recall: 0.7620 - accuracy: 0.7970 - loss: 0.3971 - val_AUC: 0.9039 - val_Precision: 0.9151 - val_Recall: 0.6736 - val_accuracy: 0.8056 - val_loss: 0.5445
# Epoch 11/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - AUC: 0.9158 - Precision: 0.8257 - Recall: 0.8133 - accuracy: 0.8220 - loss: 0.3710
# Epoch 11: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 119ms/step - AUC: 0.9157 - Precision: 0.8264 - Recall: 0.8122 - accuracy: 0.8217 - loss: 0.3714 - val_AUC: 0.9122 - val_Precision: 0.8095 - val_Recall: 0.8264 - val_accuracy: 0.8160 - val_loss: 0.3954
# Epoch 12/20
# 37/50 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.8790 - Precision: 0.8112 - Recall: 0.6997 - accuracy: 0.7515 - loss: 0.4512
# Epoch 12: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - AUC: 0.8831 - Precision: 0.8151 - Recall: 0.7073 - accuracy: 0.7560 - loss: 0.4432 - val_AUC: 0.9160 - val_Precision: 0.7457 - val_Recall: 0.8958 - val_accuracy: 0.7951 - val_loss: 0.4029
# Epoch 13/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - AUC: 0.9620 - Precision: 0.9687 - Recall: 0.8470 - accuracy: 0.8960 - loss: 0.2712
# Epoch 13: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - AUC: 0.9613 - Precision: 0.9675 - Recall: 0.8459 - accuracy: 0.8948 - loss: 0.2728 - val_AUC: 0.9004 - val_Precision: 0.7238 - val_Recall: 0.9097 - val_accuracy: 0.7812 - val_loss: 0.5341
# Epoch 14/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - AUC: 0.9386 - Precision: 0.8587 - Recall: 0.9341 - accuracy: 0.8966 - loss: 0.3209
# Epoch 14: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - AUC: 0.9378 - Precision: 0.8577 - Recall: 0.9329 - accuracy: 0.8954 - loss: 0.3227 - val_AUC: 0.8786 - val_Precision: 0.6618 - val_Recall: 0.9375 - val_accuracy: 0.7292 - val_loss: 0.6409
# Epoch 15/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - AUC: 0.8605 - Precision: 0.6660 - Recall: 0.7596 - accuracy: 0.7271 - loss: 0.5016
# Epoch 15: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - AUC: 0.8613 - Precision: 0.6683 - Recall: 0.7605 - accuracy: 0.7287 - loss: 0.4996 - val_AUC: 0.9186 - val_Precision: 0.7485 - val_Recall: 0.8681 - val_accuracy: 0.7882 - val_loss: 0.4096
# Epoch 16/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - AUC: 0.9138 - Precision: 0.8754 - Recall: 0.7703 - accuracy: 0.8223 - loss: 0.3763
# Epoch 16: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - AUC: 0.9133 - Precision: 0.8749 - Recall: 0.7705 - accuracy: 0.8223 - loss: 0.3771 - val_AUC: 0.9065 - val_Precision: 0.6821 - val_Recall: 0.9236 - val_accuracy: 0.7465 - val_loss: 0.5359
# Epoch 17/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - AUC: 0.9410 - Precision: 0.8984 - Recall: 0.8658 - accuracy: 0.8728 - loss: 0.3226
# Epoch 17: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - AUC: 0.9413 - Precision: 0.8987 - Recall: 0.8662 - accuracy: 0.8732 - loss: 0.3216 - val_AUC: 0.8948 - val_Precision: 0.6408 - val_Recall: 0.9167 - val_accuracy: 0.7014 - val_loss: 0.7606
# Epoch 18/20
# 39/50 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - AUC: 0.8011 - Precision: 0.8370 - Recall: 0.7078 - accuracy: 0.7375 - loss: 0.5649
# Epoch 18: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - AUC: 0.8157 - Precision: 0.8227 - Recall: 0.7242 - accuracy: 0.7459 - loss: 0.5431 - val_AUC: 0.8137 - val_Precision: 0.6303 - val_Recall: 0.9236 - val_accuracy: 0.6910 - val_loss: 0.8248
# Epoch 19/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - AUC: 0.8404 - Precision: 0.8216 - Recall: 0.7378 - accuracy: 0.7460 - loss: 0.5298
# Epoch 19: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - AUC: 0.8401 - Precision: 0.8198 - Recall: 0.7386 - accuracy: 0.7457 - loss: 0.5300 - val_AUC: 0.8716 - val_Precision: 0.6172 - val_Recall: 0.8958 - val_accuracy: 0.6701 - val_loss: 0.7175
# Epoch 20/20
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - AUC: 0.9124 - Precision: 0.7742 - Recall: 0.8788 - accuracy: 0.8241 - loss: 0.3968
# Epoch 20: val_accuracy did not improve from 0.90972
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 142ms/step - AUC: 0.9132 - Precision: 0.7758 - Recall: 0.8790 - accuracy: 0.8251 - loss: 0.3948 - val_AUC: 0.9312 - val_Precision: 0.7888 - val_Recall: 0.8819 - val_accuracy: 0.8229 - val_loss: 0.3559

# %%
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.savefig('Efficientnet-acc.png')
plt.show()
# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.savefig('Efficientnet-loss.png')
plt.show()

# %%
model.evaluate(test_generator)
# Out:
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - AUC: 0.9568 - Precision: 0.9416 - Recall: 0.8728 - accuracy: 0.8895 - loss: 0.2763
# [0.25628408789634705,
#  0.9611461758613586,
#  0.9475982785224915,
#  0.8611111044883728,
#  0.8886256217956543]

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img('../input/thermography-images-of-diabetic-foot/ThermoDataBase/val/DM Group/DM004_M_L.png',target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=ypred[0]
if a<0.5:
      op="Normal"   
else:
      op="Diabetic"
plt.imshow(img)
print("THE UPLOADED THERMAL IMAGE IS SUSPECTED AS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step
# [[0.7062094]]
# THE UPLOADED THERMAL IMAGE IS SUSPECTED AS: Diabetic

# %%
from tensorflow.keras.utils import load_img, img_to_array
img = load_img('/kaggle/input/thermography-images-of-diabetic-foot/ThermoDataBase/val/Control Group/CG001_M_L-rotated1-rotated1.png',target_size=(224,224))
imag = img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=ypred[0]
if a<0.5:
      op="Normal"   
else:
      op="Diabetic"
plt.imshow(img)
print("THE UPLOADED THERMAL IMAGE IS SUSPECTED AS: "+str(op))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.06081719]]
# THE UPLOADED THERMAL IMAGE IS SUSPECTED AS: Normal
